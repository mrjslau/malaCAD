# %%
# Choose set for plotting
SET = 'rot270'

# %%
import numpy as np
import pandas as pd
from imageio import imread

import matplotlib.pyplot as plt

# %%
SET_DIR = '../sets/' + SET + '/'
TRAIN_IMG_DIR = SET_DIR + 'nodules/train/'
TEST_IMG_DIR = SET_DIR + 'nodules/test/'
VAL_IMG_DIR = SET_DIR + 'nodules/val/'
IMG_PREF = 'nodule_'
IMG_EXT = '.jpg'

# %%
X_df = pd.read_pickle(SET_DIR + 'pickle/traindata')
y_df = pd.read_pickle(SET_DIR + 'pickle/trainlabels')
pos_df = X_df[y_df == 1]
pos_df.head()
# Out:
#                                                 seriesuid      coordX  \
# 214850  1.3.6.1.4.1.14519.5.2.1.6279.6001.217589936421...  141.480000
# 527637  1.3.6.1.4.1.14519.5.2.1.6279.6001.892375496445...   57.918526
# 464602  1.3.6.1.4.1.14519.5.2.1.6279.6001.534083630500...  -86.800000
# 22656   1.3.6.1.4.1.14519.5.2.1.6279.6001.112767175295...  -27.635385
# 21367   1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331...   40.690000
#
#            coordY      coordZ
# 214850  22.700000 -242.290000
# 527637  14.704181  -81.781767
# 464602  56.070000 -112.260000
# 22656   39.519795 -168.655741
# 21367   32.190000  -97.150000

# %%
plt.figure(figsize = (20, 15))
plt.subplot(141)
img = imread(TRAIN_IMG_DIR + IMG_PREF + str(214850) + IMG_EXT)
plt.imshow(img, cmap='gray')
plt.subplot(142)
img = imread(TRAIN_IMG_DIR + IMG_PREF + str(1214850) + IMG_EXT)
plt.imshow(img, cmap='gray')
plt.subplot(143)
img = imread(TRAIN_IMG_DIR + IMG_PREF + str(2214850) + IMG_EXT)
plt.imshow(img, cmap='gray')
plt.subplot(144)
img = imread(TRAIN_IMG_DIR + IMG_PREF + str(3214850) + IMG_EXT)
plt.imshow(img, cmap='gray')
